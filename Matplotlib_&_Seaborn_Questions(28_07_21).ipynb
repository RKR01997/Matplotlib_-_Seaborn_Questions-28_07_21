# %% [markdown]
# <a href="https://colab.research.google.com/github/11AJ/ML_projects_TGC/blob/main/Matplotlib_%26_Seaborn_Questions(28_07_21).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1) Read the dataset<br>

# %%
df=pd.read_excel('/content/Coffee.xlsx')

# %%
df.head(5)
# Out:
#    Area Code   Date   Market  ... Profit Sales Total Expenses
# 0        719  40909  Central  ...     94   219             36
# 1        970  40909  Central  ...     68   190             39
# 2        970  40909  Central  ...    101   234             38
# 3        303  40909  Central  ...     30   100             26
# 4        303  40909  Central  ...     54   134             26
#
# [5 rows x 20 columns]

# %% [markdown]
# 2) Remove/handle the null values<br>

# %%
df.isnull().sum()
# Out:
# Area Code         0
# Date              0
# Market            0
# Market Size       0
# Product           0
# Product Line      0
# Product Type      0
# State             0
# Type              0
# Budget COGS       0
# Budget Margin     0
# Budget Profit     0
# Budget Sales      0
# COGS              0
# Inventory         0
# Margin            0
# Marketing         0
# Profit            0
# Sales             0
# Total Expenses    0
# dtype: int64

# %% [markdown]
# 3) Depict different Market types and their count on a bar chart

# %%
d1=df['Market'].value_counts()

# %%
plt.bar(d1.index,d1,color='red')
plt.ylim(0,1500)
plt.xlabel('Market')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 4) Depict different Product types and their count on a line chart

# %%
d2=df['Product Type'].value_counts()

# %%
plt.plot(d2.index,d2,marker='*',color='red')
plt.xlabel('Product Type')
plt.grid()
plt.show()

# %% [markdown]
# 5) Depict different State and their count on a pie chart

# %%
d3=df['State'].value_counts()

# %%
plt.pie(d3,labels=d3.index,autopct='%.2f%%')
plt.legend(loc=(2,0))
plt.figure(figsize=(30,30))
plt.show()

# %% [markdown]
# 6) Depict Market wise sum of Profit and depict the result on bar chart.

# %%
d4=df.groupby(['Market'])['Profit'].sum()

# %%
plt.bar(d4.index,d4,color='red')
plt.show()

# %% [markdown]
# 7) Depict Product wise mean of Sales and depict the result on bar chart and line chart superimposed

# %%
d6=df.groupby(['Product'])['Sales'].mean()

# %%
plt.bar(d6.index,d6,color='red')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 8) Depcit Profit vs Sales on a Scatter Chart where Product is 'Regular Espresso'

# %%
df['Product'].value_counts()
# Out:
# Lemon                480
# Caffe Mocha          480
# Colombian            480
# Decaf Espresso       408
# Darjeeling           384
# Decaf Irish Cream    384
# Chamomile            384
# Green Tea            288
# Earl Grey            288
# Caffe Latte          216
# Amaretto             192
# Mint                 192
# Regular Espresso      72
# Name: Product, dtype: int64

# %%
d7 = df[df['Product']=='Regular Espresso']
d7.shape
# Out:
# (72, 20)

# %%
plt.scatter(d7['Profit'],d7['Sales'],marker='*',color='red')
plt.show()

# %% [markdown]
# 9) Depcit Budget Profit vs Budget Sales on a Scatter Chart where State is California and Product is 'Earl Grey'

# %%
df['State'].value_counts()
# Out:
# Utah             288
# California       288
# Oregon           264
# Nevada           264
# Colorado         264
# Washington       240
# Wisconsin        216
# Ohio             216
# Florida          216
# Missouri         216
# Illinois         216
# Iowa             216
# New York         192
# New Mexico       168
# Connecticut      168
# New Hampshire    168
# Texas            168
# Oklahoma         168
# Louisiana        168
# Massachusetts    144
# Name: State, dtype: int64

# %%
d8=df[(df['State']=='California') & (df['Product']=='Earl Grey')]
d8.shape
# Out:
# (24, 20)

# %%
plt.scatter(d8['Budget Profit'],d8['Budget Sales'],marker='o')
plt.show()

# %% [markdown]
# 10) Depcit Market wise mean of Budget Sales and mean of Sales in a stacked bar chart

# %%
d9=df.groupby(['Market'])['Budget Sales'].mean()

# %%
d10=df.groupby(['Market'])['Sales'].mean()

# %%
plt.bar(d10.index,d10,color='red')
plt.bar(d9.index,d9,color='Blue')
plt.show()

# %% [markdown]
# 1) Plot the Frequency distribution of Total Expenses

# %%
plt.hist(df['Total Expenses'])
plt.show()

# %% [markdown]
# 12) Compare Frequency Distribution of Profit and Budget Profit on a histogram for the Oregon State

# %%
d11=df[df['State']=='Oregon']

# %%
plt.hist(d11['Profit'])
plt.hist(d11['Budget Profit'])

plt.show()

# %% [markdown]
# 13) Compare Frequency of COGS and Budget COGS on a histogram for the Eastern Market for the Product Cafe Mocha

# %%
df['Market'].value_counts()
# Out:
# Central    1344
# West       1344
# East        888
# South       672
# Name: Market, dtype: int64

# %%
d12=df[(df['Market']=='East') & (df['Product']=='Cafe Mocha')]
d12.shape
# Out:
# (0, 20)

# %%
plt.hist(d12['Budget COGS'])
plt.hist(d12['COGS'])
plt.show()

# %% [markdown]
# 14) Compare Sales vs Profit on a histogram for the Eastern or Central Market and for Decaf Type

# %%
d13=df[((df['Market']=='East') | (df['Market']=='Central')) & (df['Type']=='Decaf') ]

# %%
plt.hist(d13['Sales'],facecolor='red',edgecolor='blue')
plt.hist(d13['Profit'],edgecolor='red',facecolor='blue')
plt.show()

# %% [markdown]
# 15) Depict the quartile distribution of COGS where Sales is greater than 400

# %%
d14=df[df['Sales']>400]

# %%
plt.boxplot(d14['COGS'])
plt.ylim(0,500)
plt.show()

# %% [markdown]
# 16) Depict the quartile distribution of Budget Profit for Decaf Espresso

# %%
d15=df[(df['Type']=='Decaf')&(df['Product Type']=='Espresso')]

# %%
plt.boxplot(d15['Budget Profit'])
plt.show()

# %% [markdown]
# 17) Find the Market, Product and Type where Sales is maximum
#
#
# Ans.   West ,Espresso,Regular

# %%
df.groupby(['Market']).sum()
# Out:
#          Area Code      Date  Budget COGS  ...  Profit   Sales  Total Expenses
# Market                                     ...
# Central     775889  55451984       104220  ...   93852  265045           69033
# East        551756  36637918        64500  ...   59217  178576           50113
# South       364466  27725992        40740  ...   32478  103926           31002
# West        781406  55451984       108420  ...   73996  272264           79514
#
# [4 rows x 13 columns]

# %%
df.groupby(['Product Type']).sum()
# Out:
#               Area Code      Date  Budget COGS  ...  Profit   Sales  Total Expenses
# Product Type                                    ...
# Coffee           617264  43569416        96880  ...   74683  216828           60025
# Espresso         666599  48520486        90800  ...   68620  222996           64603
# Herbal Tea       622188  43569416        73060  ...   63254  207214           57814
# Tea              567466  39608560        57140  ...   52986  172773           47220
#
# [4 rows x 13 columns]

# %%
df.groupby(['Type']).sum()
# Out:
#          Area Code      Date  Budget COGS  ...  Profit   Sales  Total Expenses
# Type                                       ...
# Decaf      1072834  76246478       136940  ...  106745  347624           96487
# Regular    1400683  99021400       180940  ...  152798  472187          133175
#
# [2 rows x 13 columns]

# %% [markdown]
# # **PANDAS PLOT**

# %%
df.head(5)
# Out:
#    Area Code   Date   Market  ... Profit Sales Total Expenses
# 0        719  40909  Central  ...     94   219             36
# 1        970  40909  Central  ...     68   190             39
# 2        970  40909  Central  ...    101   234             38
# 3        303  40909  Central  ...     30   100             26
# 4        303  40909  Central  ...     54   134             26
#
# [5 rows x 20 columns]

# %% [markdown]
# 22) Depict Market and Type wise sum of Budget Profit on a bar chart

# %%
d16=df.groupby(['Market','Type'])['Budget Profit'].sum()

# %%
d16.plot(kind='bar',color='red')
plt.show()

# %% [markdown]
# 23) Depict Product Type and State wise mean of Sales on a bar chart

# %%
d17=df.groupby(['Product Type','State'])['Sales'].mean()

# %%
d17.plot(kind='bar',color='red',figsize=(35,10))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 24) Depict Product and Type wise sum of Budget COGS on a line Chart

# %%
d18=df.groupby(['Product','Type'])['Budget COGS'].sum()

# %%
d18.plot(kind='line',color='red',figsize=(20,5),xlabel='(Product,Type)')
plt.show()

# %% [markdown]
# 25) Depict Product and Type wise sum of Budget Profit and Budget Sales on a line Chart

# %%
d19=df.groupby(['Product','Type'])['Budget Profit'].sum()
d20=df.groupby(['Product','Type'])['Budget Sales'].sum()

# %%
d19.plot(kind='line',color='red',figsize=(15,5))
d20.plot(kind='line',color='blue',figsize=(15,5))
plt.legend()
plt.show()

# %% [markdown]
# 26) Depict Market and Product Type based mean of Sales on abar chart and on a stacked bar chart separately

# %%
d21=df.groupby(['Market','Product Type'])['Sales'].mean()

# %%
d21.plot(kind='bar',stacked=True)
plt.show()

# %%
d22=d21.unstack()
d22
# Out:
# Product Type      Coffee    Espresso  Herbal Tea         Tea
# Market
# Central       179.895833  207.295139  202.047619  203.500000
# East          337.148810  201.654167  191.486111  121.882576
# South         173.223958  156.215278  133.734375         NaN
# West          185.410256  194.188889  231.692308  200.611111

# %%
d22.plot(kind='bar',stacked=True,figsize=(7,5))
plt.legend()
plt.show()

# %% [markdown]
# 27) Find State and Market Size based mean of Sales and COGS where Market is not Central and Profit is over 350. Depict the result on a line chart and stacked bar separately

# %%
d23=df[(df['Market']!='Central')&(df['Profit']>350)]
d23.shape
# Out:
# (65, 20)

# %%
d24=df.groupby(['State','Market Size'])['Sales','COGS'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
d24.plot(kind='line',color=('red','blue'),figsize=(14,5),marker=('d'))
plt.show()

# %%
d25=d24.unstack()

# %%
d25.plot(kind='bar',stacked=True,figsize=(10,5))
plt.show()

# %% [markdown]
# 28) Find Product and Market Size based mean of Budget COGS and Inventory where Type is Regular and neither product or its Type is Espresso. Depict the result on a line chart and stacked bar separately

# %%
df['Type'].value_counts()
# Out:
# Regular    2400
# Decaf      1848
# Name: Type, dtype: int64

# %%
d26=df[(df['Type']=='Regular')&((df['Product']!='Espresso')&(df['Product Type']!='Espresso'))]

# %%
d27=df.groupby(['Product','Market Size'])['Budget COGS','Inventory'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
d27.plot(kind='line',color=('red','blue'),figsize=(15,5),marker='*')
plt.show()

# %%
d28=d27.unstack()

# %%
d28.plot(kind='bar',stacked=True,figsize=(10,5))
plt.show()

# %% [markdown]
# # **SEABORN PLOTS**

# %% [markdown]
# 1) Depict Product based on Market Size on a count plot

# %%
sns.countplot(x=df['Product'],hue=df['Market Size'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 2) Depict State based on Market on a count plot

# %%
sns.countplot(x=df['State'],hue=df['Market'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 3) Depict the Product Type vs Total Expenses on a Violin Plot based on Market

# %%
sns.violinplot(x=df['Total Expenses'],hue=df['Product Type'],color='red')
plt.show()

# %% [markdown]
# 4) Depict Market vs Budget COGS on a boxplot

# %%
sns.boxplot(x=df['Market'],y=df['Budget COGS'])
plt.show()

# %% [markdown]
# 5) Depict Product vs Margin on a boxplot based on Market Size

# %%
sns.boxplot(x=df['Product'],y=df['Margin'],hue=df['Market Size'])
plt.xticks(rotation=90)
plt.figure(figsize=(20,10))
plt.show()

# %% [markdown]
# 6) Depict the Market vs Budget Sales on a Violin Plot based on Product Type where product is Colombina or Darjeeling

# %%
df['Product'].value_counts()
# Out:
# Lemon                480
# Caffe Mocha          480
# Colombian            480
# Decaf Espresso       408
# Darjeeling           384
# Decaf Irish Cream    384
# Chamomile            384
# Green Tea            288
# Earl Grey            288
# Caffe Latte          216
# Amaretto             192
# Mint                 192
# Regular Espresso      72
# Name: Product, dtype: int64

# %%
d29=df[(df['Product']=='Colombian')|(df['Product']=='Darjeeling')]
d29.shape
# Out:
# (864, 20)

# %%
sns.violinplot(x=d29['Market'],y=d29['Budget Sales'],hue=d29['Product'])
plt.show()

# %% [markdown]
# 7) Depict the Product vs Inventory on a Box Plot based on Product Type where State is California or Nevada

# %%
d30=df[(df['State']=='California')|(df['State']=='Nevada')]

# %%
sns.boxplot(x=d30['Product'],y=d30['Inventory'],hue=d30['State'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 8) Generate Pairplot for the Coffee dataset where Type is Regular including fields- Budget Sales, Budget Profit, Budget COGS, Sales, Proift and COGS

# %%
d31=df[(df['Type']=='Regular')]

# %%
sns.pairplot(d31,vars=['Budget Sales','Budget Profit','Budget COGS','Sales','Profit','COGS'])
plt.show()

# %% [markdown]
# 9) Generate Pairplot for the Coffee dataset where Profit is over 250 based on Type including fields- Budget Sales, Budget Profit, Budget COGS, Sales, Proift and COGS

# %%
d32=df[(df['Profit']>250)]

# %%
sns.pairplot(d32,vars=['Budget Sales', 'Budget Profit', 'Budget COGS', 'Sales', 'Profit','COGS'])
plt.show()

# %% [markdown]
# 10) Generate Pairplot for the Coffee dataset where Market is Western or Central based and Product Line is beans based on Type including fields- COGS, Sales, Proift and Total Expenses

# %%
d33=df[((df['Market']=='West')|(df['Market']=='Central'))&(df['Product Line']=='Beans')]

# %%
sns.pairplot(d33,vars=['COGS','Sales','Profit','Total Expenses'])
plt.show()

# %% [markdown]
# 11) Depict Market vs Total Expenses based on Type on a Swarm Plot where Sales is over 200 and Market Size is Small

# %%
d34=df[(df['Sales']>200)&(df['Market Size']=='Small')]

# %%
sns.swarmplot(x=df['Market'],y=df['Total Expenses'],hue=df['Type'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 74.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 61.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 64.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 69.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# 12) Depict correlation values on a heatmap

# %%
corr=df.corr()

# %%
sns.heatmap(corr,annot=True)
plt.show()
